# %% [markdown]
# ### PART 1: Data Cleaning Cadance
# 1. Inspect data for structure and data types
# 2. Inspect for missing values
# 3. Check for duplicates in data
# 4. Check for outliers
# 5. Miss-labeling and spurious data entries
# 6. Inspect data columns for data types

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv( "C://Users/Modupe/Documents/Py workspace/Strike and Academic Performance  (UNILAG).csv")

# %%
#Inspect data for structure and data type

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 431 entries, 0 to 430
# Data columns (total 24 columns):
#  #   Column                                                                                                                    Non-Null Count  Dtype
# ---  ------                                                                                                                    --------------  -----
#  0   Timestamp                                                                                                                 431 non-null    object
#  1   Are you a student of the University of Lagos?                                                                             431 non-null    object
#  2   If not, what is your university/institution?                                                                              22 non-null     object
#  3   What is your current academic level?                                                                                      431 non-null    object
#  4   How old are you?                                                                                                          431 non-null    int64
#  5   What is your gender?                                                                                                      431 non-null    object
#  6   What was your relationship status during the strike?                                                                      431 non-null    object
#  7   What is your faculty?                                                                                                     431 non-null    object
#  8   What is your department?                                                                                                  431 non-null    object
#  9   Kindly input your department, if not listed in the previous question.                                                     28 non-null     object
#  10  How has the ASUU strike affected you and your academic performance?                                                       345 non-null    object
#  11  What was the most challenging part of returning to academic life after the strike?                                        340 non-null    object
#  12  Did you undertake any work during the strike?                                                                             431 non-null    object
#  13  How did you develop yourself during the strike?                                                                           431 non-null    object
#  14  How prepared were you for the exams? [Before Strike]                                                                      431 non-null    object
#  15  How prepared were you for the exams? [After Strike]                                                                       431 non-null    object
#  16  How were your lectures affected by the strike?                                                                            431 non-null    object
#  17  How often did you engage in academic activities during the strike?                                                        431 non-null    object
#  18  How many courses did you take in the affected semester?                                                                   431 non-null    int64
#  19  How many credit units did your courses add up to in the affected semester?                                                353 non-null    float64
#  20  What was your CGPA before the strike?                                                                                     431 non-null    float64
#  21  What is your current CGPA?                                                                                                431 non-null    float64
#  22  Would you like to be contacted for follow-up questions or an interview? If yes, kindly provide your email address below.  87 non-null     object
#  23  How did you hear about this survey?                                                                                       252 non-null    object
# dtypes: float64(3), int64(2), object(19)
# memory usage: 80.9+ KB

# %%
#Inspect data for structure and data type

df.isna().sum()
# Out:
# Timestamp                                                                                                                     0
# Are you a student of the University of Lagos?                                                                                 0
# If not, what is your university/institution?                                                                                409
# What is your current academic level?                                                                                          0
# How old are you?                                                                                                              0
# What is your gender?                                                                                                          0
# What was your relationship status during the strike?                                                                          0
# What is your faculty?                                                                                                         0
# What is your department?                                                                                                      0
# Kindly input your department, if not listed in the previous question.                                                       403
# How has the ASUU strike affected you and your academic performance?                                                          86
# What was the most challenging part of returning to academic life after the strike?                                           91
# Did you undertake any work during the strike?                                                                                 0
# How did you develop yourself during the strike?                                                                               0
# How prepared were you for the exams? [Before Strike]                                                                          0
# How prepared were you for the exams? [After Strike]                                                                           0
# How were your lectures affected by the strike?                                                                                0
# How often did you engage in academic activities during the strike?                                                            0
# How many courses did you take in the affected semester?                                                                       0
# How many credit units did your courses add up to in the affected semester?                                                   78
# What was your CGPA before the strike?                                                                                         0
# What is your current CGPA?                                                                                                    0
# Would you like to be contacted for follow-up questions or an interview? If yes, kindly provide your email address below.    344
# How did you hear about this survey?                                                                                         179
# dtype: int64

# %%
cols = list(df.columns)

cols
# Out:
# ['Timestamp',
#  'Are you a student of the University of Lagos?',
#  'If not, what is your university/institution?',
#  'What is your current academic level?',
#  'How old are you?',
#  'What is your gender?',
#  'What was your relationship status during the strike?',
#  'What is your faculty?',
#  'What is your department?',
#  'Kindly input your department, if not listed in the previous question. ',
#  'How has the ASUU strike affected you and your academic performance?',
#  'What was the most challenging part of returning to academic life after the strike?',
#  'Did you undertake any work during the strike?',
#  'How did you develop yourself during the strike?',
#  'How prepared were you for the exams? [Before Strike]',
#  'How prepared were you for the exams? [After Strike]',
#  'How were your lectures affected by the strike?',
#  'How often did you engage in academic activities during the strike?',
#  'How many courses did you take in the affected semester? ',
#  'How many credit units did your courses add up to in the affected semester?',
#  'What was your CGPA before the strike?',
#  'What is your current CGPA?',
#  'Would you like to be contacted for follow-up questions or an interview? If yes, kindly provide your email address below.',
#  'How did you hear about this survey?']

# %%
# Drop multiple columns
columns_to_drop = ['Timestamp',
                   'Would you like to be contacted for follow-up questions or an interview? If yes, kindly provide your email address below.', 
                   'How did you hear about this survey?']
df = df.drop(columns_to_drop, axis=1)

#df = df.drop('Timestamp', axis=1)

# %%
# to save to file as a csv file without the index column, use the pandas to_csv()
#CSV: Cover seperated value
df.to_csv('C://Users/Modupe/Documents/Github/asuu-strike-project/Strike and Academic Performance_1.csv', index=False)

# %%
# Rename multiple columns

column_mapping = {
    'Are you a student of the University of Lagos?': 'Unilag',
    'If not, what is your university/institution?': 'Non_Unilag',
    'What is your current academic level?': 'Academic_Level',
    'How old are you?': 'Age',
    'What is your gender?': 'Gender',
    'What was your relationship status during the strike?': 'Relationship_Status',
    'What is your faculty?': 'Faculty',
    'What is your department?': 'Department',
    'Kindly input your department, if not listed in the previous question. ': 'Other_Dept',
    'How has the ASUU strike affected you and your academic performance?': 'Strike_Effect',
    'What was the most challenging part of returning to academic life after the strike?': 'Challenging_Part',
    'Did you undertake any work during the strike?': 'Job_Undertaken',
    'How did you develop yourself during the strike?': 'Self_Development',
    'How prepared were you for the exams? [Before Strike]': 'Exam_Prep_Before_Strike',
    'How prepared were you for the exams? [After Strike]': 'Exam_Prep_After_Strike',
    'How were your lectures affected by the strike?': 'Lectures_Affected',
    'How often did you engage in academic activities during the strike?': 'Academic_Activities',
    'How many courses did you take in the affected semester? ': 'Courses_Taken',
    'How many credit units did your courses add up to in the affected semester?': 'Course_Unit',
    'What was your CGPA before the strike?': 'CGPA_Before',
    'What is your current CGPA?': 'CGPA_After'
}

df = df.rename(columns=column_mapping)

# %%
df.head(2)
# Out:
#   Unilag Non_Unilag Academic_Level  Age  Gender Relationship_Status  \
# 0    Yes        NaN      400 Level   22    Male              Single
# 1    Yes        NaN      400 Level   23  Female              Single
#
#        Faculty            Department Other_Dept  \
# 0  Engineering  Chemical Engineering        NaN
# 1  Engineering  Chemical Engineering        NaN
#
#                                        Strike_Effect  ...  \
# 0  I learned how to study better and my grades al...  ...
# 1  It affected it in a negative way as it became ...  ...
#
#                             Job_Undertaken  \
# 0  Worked in a role relevant to my studies
# 1           Did not work during the strike
#
#                                Self_Development Exam_Prep_Before_Strike  \
# 0  Acquired skills unrelated to course of study                  Poorly
# 1  Acquired skills unrelated to course of study                  Poorly
#
#   Exam_Prep_After_Strike     Lectures_Affected  \
# 0                 Poorly  No noticeable change
# 1             Moderately  No noticeable change
#
#                                  Academic_Activities Courses_Taken  \
# 0  Rarely: I engaged in academic activities once ...            10
# 1  Rarely: I engaged in academic activities once ...            10
#
#    Course_Unit  CGPA_Before  CGPA_After
# 0         23.0         3.39        3.51
# 1         23.0         4.44        4.50
#
# [2 rows x 21 columns]

# %%
#Creating our outcome variable column

df['CGPA Change'] = df['CGPA_After'] - df['CGPA_Before']

# %% [markdown]
# ## Solving cases concerning the department columns
#
# There are 2 columns,
# 1. 0ne contains the main department of individuals who had their department on the list while filling, and those that did not find theirs and had to specify
# 2. We have to find a way to merge them, as clearly one of the columns aren't needed

# %%
df.Department.unique()
# Out:
# array(['Chemical Engineering', 'Political Science',
#        'Computer Engineering', 'Educational Foundations', 'Statistics',
#        'Geosciences', 'Science Tech. Education',
#        'Petroleum & Gas Engineering', 'Cell Biology & Genetics',
#        'Surveying & Geo-Informatics Engineering', 'Mathematics',
#        'Finance', 'Marine Science',
#        'Industrial Relations & Personnel Management',
#        'Mechanical Engineering', 'Mass Communication',
#        'Biomedical Engineering', 'Estate', 'Other',
#        'Biochemistry (Basic Medical Sciences)', 'Law', 'Medicine',
#        'Arts & Social Science Education', 'Zoology',
#        'Biochemistry (Sciences)', 'Education Administration', 'Botany',
#        'Economics', 'Systems Engineering', 'Psychology', 'Accounting',
#        'Physics', 'Radiology', 'Electrical & Electronics Engineering',
#        'Geography', 'Microbiology', 'Chemistry', 'Architecture',
#        'Biology Education', 'Human Kinetics & Health Education',
#        'Physiology', 'Adult Education',
#        'Civil & Environmental Engineering', 'Philosophy',
#        'Pharmaceutics & Pharmaceutical Technology', 'English',
#        'Quantity Surveying', 'Metallurgical & Materials Engineering',
#        'Actuarial Science & Insurance',
#        'European Languages & Integration Studies', 'Nursing',
#        'History & Strategic Studies', 'Computer Sciences', 'Building',
#        'Business Administration', 'Sociology', 'Restorative Dentistry',
#        'Medical Laboratory Science'], dtype=object)

# %%
df.Other_Dept.unique()
# Out:
# array([nan, 'Geophysics ', 'Radiography ', 'Biology Education ',
#        'FISHERIES ', 'Education and Biology ', 'Pharmacy ', 'Law ',
#        'Early childhood education ', 'Education Eng',
#        'Business Education ', 'Education ', 'Business Education',
#        'Religious Studies ', 'Technology and vocational education ',
#        'Communication and Language Arts ', 'Pharmacology ',
#        'Pharmacology, therapeutics and toxicology ', 'PHARMACY ',
#        'Pharmacy', 'Pharmacology', 'Mechatronics Engineering.',
#        'Banking and Finance ', 'Insurance ', 'Education foundation ',
#        'Art & Social Science Education '], dtype=object)

# %%
# Replace "other" with the corresponding value from "Other_Department"
df['Department'] = df['Department'].str.lower()
df['Other_Dept'] = df['Other_Dept'].str.lower()


df['Department'] = df.apply(lambda row: row['Other_Dept'] if row['Department'] == 'other' else row['Department'], axis=1)

# %%
#Turn the rext back to proper text

df['Department'] = df['Department'].str.capitalize()

# %%
#Deal with any missing data in this column
df[df['Department'].isna()]
# Out:
#     Unilag Non_Unilag Academic_Level  Age  Gender Relationship_Status  \
# 51     Yes        NaN      200 Level   20    Male              Single
# 331    Yes        NaN      300 Level   22  Female              Single
#
#              Faculty Department Other_Dept         Strike_Effect  ...  \
# 51          Pharmacy        NaN        NaN                   NaN  ...
# 331  Social Sciences        NaN        NaN  I am mentally tired   ...
#
#                                       Self_Development  \
# 51        Acquired skills unrelated to course of study
# 331  Volunteered for an event or organization, Acqu...
#
#     Exam_Prep_Before_Strike Exam_Prep_After_Strike  \
# 51               Moderately             Moderately
# 331              Moderately                 Poorly
#
#                     Lectures_Affected  \
# 51   Fewer lecturers attended classes
# 331              No noticeable change
#
#                                    Academic_Activities Courses_Taken  \
# 51   Often: I engaged in academic activities regula...             7
# 331  Rarely: I engaged in academic activities once ...             7
#
#     Course_Unit  CGPA_Before  CGPA_After  CGPA Change
# 51          NaN          5.0        4.89        -0.11
# 331        18.0          0.0        0.00         0.00
#
# [2 rows x 22 columns]

# %%
#For location 51

df.loc[51, 'Department'] = 'Pharmacy'

df.loc[51, 'Course_Unit'] = 18.0

# %%
# Drop row with index 331 and reindex the DataFrame
df.drop(331, inplace=True)
df.reset_index(drop=True, inplace=True)

# %%
df['Department'].value_counts()
# Out:
# Cell biology & genetics       34
# Chemical engineering          22
# Accounting                    22
# Educational foundations       19
# Finance                       19
#                               ..
# Education and biology          1
# Pharmacy                       1
# Fisheries                      1
# Biomedical engineering         1
# Medical laboratory science     1
# Name: Department, Length: 76, dtype: int64

# %%
len(df['Department'])
# Out:
# 430

# %%
df.drop(columns=['Other_Dept'], inplace=True)
df.head(2)
# Out:
#   Unilag Non_Unilag Academic_Level  Age  Gender Relationship_Status  \
# 0    Yes        NaN      400 Level   22    Male              Single
# 1    Yes        NaN      400 Level   23  Female              Single
#
#        Faculty            Department  \
# 0  Engineering  Chemical engineering
# 1  Engineering  Chemical engineering
#
#                                        Strike_Effect  \
# 0  I learned how to study better and my grades al...
# 1  It affected it in a negative way as it became ...
#
#                                     Challenging_Part  ...  \
# 0  Trying to remember things we were taught befor...  ...
# 1  Rekindling the student in me, lol. Trying to g...  ...
#
#                                Self_Development Exam_Prep_Before_Strike  \
# 0  Acquired skills unrelated to course of study                  Poorly
# 1  Acquired skills unrelated to course of study                  Poorly
#
#   Exam_Prep_After_Strike     Lectures_Affected  \
# 0                 Poorly  No noticeable change
# 1             Moderately  No noticeable change
#
#                                  Academic_Activities Courses_Taken  \
# 0  Rarely: I engaged in academic activities once ...            10
# 1  Rarely: I engaged in academic activities once ...            10
#
#    Course_Unit  CGPA_Before  CGPA_After  CGPA Change
# 0         23.0         3.39        3.51         0.12
# 1         23.0         4.44        4.50         0.06
#
# [2 rows x 21 columns]

# %%
#Checking unique values in a column
#Aids in finding spurious data and mislabelling

df.Gender.unique()
# Out:
# array(['Male', 'Female'], dtype=object)

# %% [markdown]
# ### We would like to extract a df of students that are not from unilag for future analysis

# %%
df_non_unilag = df[df['Unilag'] == "No"] 

len(df_non_unilag)
# Out:
# 17

# %%
df_non_unilag.head(17)
# Out:
#     Unilag                                         Non_Unilag  \
# 32      No  Federal University of Petroleum Resources Effu...
# 50      No                                    OOU OGUN STATE
# 97      No                              University of Ibadan
# 132     No  Alex Ekwueme Federal University Ndufu-Alike Ik...
# 135     No                               University of ibadan
# 143     No                             Lagos state University
# 145     No                                             Funaab
# 149     No                                 University of Uyo
# 153     No                                University of Abuja
# 207     No                                                NaN
# 227     No                                             FUNAAB
# 236     No                            Lagos State University
# 305     No                              University of Ibadan
# 350     No                             Bayero University Kano
# 351     No                              University of Nigeria
# 352     No                      University of Nigeria Nsukka
# 354     No                                                 UI
#
#       Academic_Level  Age  Gender Relationship_Status  \
# 32         300 Level   20  Female              Single
# 50         500 Level   23    Male              Single
# 97         300 Level   22    Male              Single
# 132        300 Level   23  Female              Single
# 135  Masters Program   26  Female              Single
# 143        300 Level   22    Male              Single
# 145        400 Level   21    Male              Single
# 149        400 Level   20    Male         Complicated
# 153        400 Level   23  Female              Single
# 207        200 Level   20    Male              Dating
# 227        400 Level   21    Male              Single
# 236        400 Level   21  Female              Dating
# 305        100 Level   20  Female              Single
# 350        400 Level   25    Male              Single
# 351        400 Level   21    Male              Single
# 352  Masters Program   23  Female              Single
# 354        400 Level   21    Male              Single
#
#                       Faculty                            Department  \
# 32                Engineering                  Chemical engineering
# 50               AGRICULTURE                             Fisheries
# 97            Social Sciences                             Economics
# 132    Basic Medical Sciences                            Physiology
# 135    Basic Medical Sciences                          Microbiology
# 143                      Arts                            Philosophy
# 145                  Sciences                            Statistics
# 149               Engineering  Electrical & electronics engineering
# 153                      Arts                               English
# 207                  Sciences               Cell biology & genetics
# 227         Physical sciences                            Statistics
# 236                      Arts                               English
# 305                      Arts      Communication and language arts
# 350               Engineering             Mechatronics engineering.
# 351           Social Sciences                            Philosophy
# 352  Business administration                   Banking and finance
# 354           Social Sciences                            Accounting
#
#                                          Strike_Effect  \
# 32                                           No effect
# 50                                                 NaN
# 97   Reduced enthusiasm for academic related activi...
# 132  It made me slack,I don't know what I'm doing i...
# 135  Not really, it was just more difficult than ea...
# 143     No strike for Lasu, so basically work as usual
# 145                                            Too bad
# 149                                       Not o badly
# 153  The ASSU strike affected me badly. I felt like...
# 207  It affected it negatively. 8 months at home ma...
# 227                             It made my grades drop
# 236  I have become more relaxed and this has affect...
# 305                                                NaN
# 350  The ASUU strike affected me pretty bad because...
# 351                                                NaN
# 352                                                NaN
# 354                                                NaN
#
#                                       Challenging_Part  ...  \
# 32                          Reading and going to class  ...
# 50                                                 NaN  ...
# 97                                         Refocusing   ...
# 132                             Studying school books   ...
# 135  Going back to lecture room was quite difficult...  ...
# 143  Peeps from other schools were running faster a...  ...
# 145      To start reading again is an issue on its own  ...
# 149  Getting into tech then balancing it with schoo...  ...
# 153  Adjusting to reading academic materials. \nIn ...  ...
# 207                          Returning back to reading  ...
# 227     Trying to catch up with previous academic work  ...
# 236  It was hard getting back to the usual routine ...  ...
# 305                                                NaN  ...
# 350  Getting myself to study within a short timefra...  ...
# 351                                                NaN  ...
# 352                                                NaN  ...
# 354                                                NaN  ...
#
#                                       Self_Development  \
# 32                                   None of the above
# 50        Acquired skills unrelated to course of study
# 97         Acquired skills relevant to course of study
# 132           Volunteered for an event or organization
# 135       Acquired skills unrelated to course of study
# 143  Volunteered for an event or organization, Acqu...
# 145        Acquired skills relevant to course of study
# 149  Acquired skills relevant to course of study, A...
# 153  Volunteered for an event or organization, Acqu...
# 207                Vocational training and artisanship
# 227       Acquired skills unrelated to course of study
# 236  Acquired skills unrelated to course of study, ...
# 305  Acquired skills relevant to course of study, A...
# 350       Acquired skills unrelated to course of study
# 351       Acquired skills unrelated to course of study
# 352  Volunteered for an event or organization, Acqu...
# 354                                  None of the above
#
#     Exam_Prep_Before_Strike Exam_Prep_After_Strike  \
# 32                     Very                   Very
# 50                     Very             Moderately
# 97               Moderately             Moderately
# 132                  Poorly             Moderately
# 135                    Very             Moderately
# 143              Moderately             Moderately
# 145              Moderately                 Poorly
# 149              Moderately             Moderately
# 153              Moderately             Moderately
# 207              Moderately                 Poorly
# 227                  Poorly                 Poorly
# 236                    Very             Moderately
# 305              Moderately                   Very
# 350                    Very             Moderately
# 351              Moderately                 Poorly
# 352                    Very             Moderately
# 354                    Very             Moderately
#
#                                   Lectures_Affected  \
# 32                 Fewer lecturers attended classes
# 50                  Worse lectures after the strike
# 97                  Worse lectures after the strike
# 132                Fewer lecturers attended classes
# 135                            No noticeable change
# 143                Fewer lecturers attended classes
# 145                Fewer lecturers attended classes
# 149                 Worse lectures after the strike
# 153                 Worse lectures after the strike
# 207                            No noticeable change
# 227                            No noticeable change
# 236                 Worse lectures after the strike
# 305                 Worse lectures after the strike
# 350  I did not attend any lectures after the strike
# 351                 Worse lectures after the strike
# 352                            No noticeable change
# 354                Fewer lecturers attended classes
#
#                                    Academic_Activities Courses_Taken  \
# 32   Rarely: I engaged in academic activities once ...            11
# 50   Rarely: I engaged in academic activities once ...             9
# 97   Never: I did not engage in any academic activi...            10
# 132  Rarely: I engaged in academic activities once ...             9
# 135  Never: I did not engage in any academic activi...             9
# 143  Very often: I engaged in academic activities a...             9
# 145  Very often: I engaged in academic activities a...             9
# 149  Never: I did not engage in any academic activi...            12
# 153  Never: I did not engage in any academic activi...            10
# 207  Sometimes: I engaged in academic activities oc...             6
# 227  Rarely: I engaged in academic activities once ...             7
# 236  Often: I engaged in academic activities regula...            10
# 305  Sometimes: I engaged in academic activities oc...             8
# 350  Rarely: I engaged in academic activities once ...            11
# 351  Rarely: I engaged in academic activities once ...             7
# 352  Sometimes: I engaged in academic activities oc...             6
# 354  Rarely: I engaged in academic activities once ...             8
#
#      Course_Unit  CGPA_Before  CGPA_After  CGPA Change
# 32          22.0         4.67        4.67         0.00
# 50          19.0         3.51        3.66         0.15
# 97          30.0         2.80        2.70        -0.10
# 132         21.0         2.95        0.00        -2.95
# 135          3.0         0.00        4.01         4.01
# 143         23.0         2.45        3.10         0.65
# 145          0.0         2.90        3.80         0.90
# 149         22.0         4.51        4.37        -0.14
# 153         30.0         3.00        2.00        -1.00
# 207         17.0         3.72        3.93         0.21
# 227         15.0         4.00        3.70        -0.30
# 236         20.0         3.45        3.15        -0.30
# 305          NaN         0.00        0.00         0.00
# 350         25.0         4.63        4.26        -0.37
# 351         18.0         4.00        3.80        -0.20
# 352         23.0         3.40        3.40         0.00
# 354          NaN         3.75        3.67        -0.08
#
# [17 rows x 21 columns]

# %%
#Data Cleaning for new df

rows_to_drop = [132, 135, 305]
df_non_unilag.drop(rows_to_drop, inplace=True)

# Reset the index
df_non_unilag.reset_index(drop=True, inplace=True)
# Out:
# C:\Users\Modupe\AppData\Local\Temp\ipykernel_8028\1543358635.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_non_unilag.drop(rows_to_drop, inplace=True)

# %%
#Fill data using mean

df_non_unilag['Course_Unit'] = df_non_unilag['Course_Unit'].fillna(df_non_unilag['Course_Unit'].median())
# Out:
# C:\Users\Modupe\AppData\Local\Temp\ipykernel_8028\3980109286.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_non_unilag['Course_Unit'] = df_non_unilag['Course_Unit'].fillna(df_non_unilag['Course_Unit'].median())

# %%
df_non_unilag
# Out:
#    Unilag                                         Non_Unilag   Academic_Level  \
# 0      No  Federal University of Petroleum Resources Effu...        300 Level
# 1      No                                    OOU OGUN STATE         500 Level
# 2      No                              University of Ibadan         300 Level
# 3      No                             Lagos state University        300 Level
# 4      No                                             Funaab        400 Level
# 5      No                                 University of Uyo         400 Level
# 6      No                                University of Abuja        400 Level
# 7      No                                                NaN        200 Level
# 8      No                                             FUNAAB        400 Level
# 9      No                            Lagos State University         400 Level
# 10     No                             Bayero University Kano        400 Level
# 11     No                              University of Nigeria        400 Level
# 12     No                      University of Nigeria Nsukka   Masters Program
# 13     No                                                 UI        400 Level
#
#     Age  Gender Relationship_Status                   Faculty  \
# 0    20  Female              Single               Engineering
# 1    23    Male              Single              AGRICULTURE
# 2    22    Male              Single           Social Sciences
# 3    22    Male              Single                      Arts
# 4    21    Male              Single                  Sciences
# 5    20    Male         Complicated               Engineering
# 6    23  Female              Single                      Arts
# 7    20    Male              Dating                  Sciences
# 8    21    Male              Single         Physical sciences
# 9    21  Female              Dating                      Arts
# 10   25    Male              Single               Engineering
# 11   21    Male              Single           Social Sciences
# 12   23  Female              Single  Business administration
# 13   21    Male              Single           Social Sciences
#
#                               Department  \
# 0                   Chemical engineering
# 1                             Fisheries
# 2                              Economics
# 3                             Philosophy
# 4                             Statistics
# 5   Electrical & electronics engineering
# 6                                English
# 7                Cell biology & genetics
# 8                             Statistics
# 9                                English
# 10             Mechatronics engineering.
# 11                            Philosophy
# 12                  Banking and finance
# 13                            Accounting
#
#                                         Strike_Effect  \
# 0                                           No effect
# 1                                                 NaN
# 2   Reduced enthusiasm for academic related activi...
# 3      No strike for Lasu, so basically work as usual
# 4                                             Too bad
# 5                                        Not o badly
# 6   The ASSU strike affected me badly. I felt like...
# 7   It affected it negatively. 8 months at home ma...
# 8                              It made my grades drop
# 9   I have become more relaxed and this has affect...
# 10  The ASUU strike affected me pretty bad because...
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
#
#                                      Challenging_Part  ...  \
# 0                          Reading and going to class  ...
# 1                                                 NaN  ...
# 2                                         Refocusing   ...
# 3   Peeps from other schools were running faster a...  ...
# 4       To start reading again is an issue on its own  ...
# 5   Getting into tech then balancing it with schoo...  ...
# 6   Adjusting to reading academic materials. \nIn ...  ...
# 7                           Returning back to reading  ...
# 8      Trying to catch up with previous academic work  ...
# 9   It was hard getting back to the usual routine ...  ...
# 10  Getting myself to study within a short timefra...  ...
# 11                                                NaN  ...
# 12                                                NaN  ...
# 13                                                NaN  ...
#
#                                      Self_Development Exam_Prep_Before_Strike  \
# 0                                   None of the above                    Very
# 1        Acquired skills unrelated to course of study                    Very
# 2         Acquired skills relevant to course of study              Moderately
# 3   Volunteered for an event or organization, Acqu...              Moderately
# 4         Acquired skills relevant to course of study              Moderately
# 5   Acquired skills relevant to course of study, A...              Moderately
# 6   Volunteered for an event or organization, Acqu...              Moderately
# 7                 Vocational training and artisanship              Moderately
# 8        Acquired skills unrelated to course of study                  Poorly
# 9   Acquired skills unrelated to course of study, ...                    Very
# 10       Acquired skills unrelated to course of study                    Very
# 11       Acquired skills unrelated to course of study              Moderately
# 12  Volunteered for an event or organization, Acqu...                    Very
# 13                                  None of the above                    Very
#
#    Exam_Prep_After_Strike                               Lectures_Affected  \
# 0                    Very                Fewer lecturers attended classes
# 1              Moderately                 Worse lectures after the strike
# 2              Moderately                 Worse lectures after the strike
# 3              Moderately                Fewer lecturers attended classes
# 4                  Poorly                Fewer lecturers attended classes
# 5              Moderately                 Worse lectures after the strike
# 6              Moderately                 Worse lectures after the strike
# 7                  Poorly                            No noticeable change
# 8                  Poorly                            No noticeable change
# 9              Moderately                 Worse lectures after the strike
# 10             Moderately  I did not attend any lectures after the strike
# 11                 Poorly                 Worse lectures after the strike
# 12             Moderately                            No noticeable change
# 13             Moderately                Fewer lecturers attended classes
#
#                                   Academic_Activities Courses_Taken  \
# 0   Rarely: I engaged in academic activities once ...            11
# 1   Rarely: I engaged in academic activities once ...             9
# 2   Never: I did not engage in any academic activi...            10
# 3   Very often: I engaged in academic activities a...             9
# 4   Very often: I engaged in academic activities a...             9
# 5   Never: I did not engage in any academic activi...            12
# 6   Never: I did not engage in any academic activi...            10
# 7   Sometimes: I engaged in academic activities oc...             6
# 8   Rarely: I engaged in academic activities once ...             7
# 9   Often: I engaged in academic activities regula...            10
# 10  Rarely: I engaged in academic activities once ...            11
# 11  Rarely: I engaged in academic activities once ...             7
# 12  Sometimes: I engaged in academic activities oc...             6
# 13  Rarely: I engaged in academic activities once ...             8
#
#     Course_Unit  CGPA_Before  CGPA_After  CGPA Change
# 0          22.0         4.67        4.67         0.00
# 1          19.0         3.51        3.66         0.15
# 2          30.0         2.80        2.70        -0.10
# 3          23.0         2.45        3.10         0.65
# 4           0.0         2.90        3.80         0.90
# 5          22.0         4.51        4.37        -0.14
# 6          30.0         3.00        2.00        -1.00
# 7          17.0         3.72        3.93         0.21
# 8          15.0         4.00        3.70        -0.30
# 9          20.0         3.45        3.15        -0.30
# 10         25.0         4.63        4.26        -0.37
# 11         18.0         4.00        3.80        -0.20
# 12         23.0         3.40        3.40         0.00
# 13         22.0         3.75        3.67        -0.08
#
# [14 rows x 21 columns]

# %% [markdown]
# ### Dataframe now only contains unilag students

# %%
#Create a new variable df that only shows Student Status as yes

df_unilag = df[df['Unilag'] != "No"] 
 
df_unilag
# Out:
#     Unilag Non_Unilag Academic_Level  Age  Gender Relationship_Status  \
# 0      Yes        NaN      400 Level   22    Male              Single
# 1      Yes        NaN      400 Level   23  Female              Single
# 2      Yes        Nil      400 Level   21    Male              Dating
# 3      Yes        NaN      400 Level   29    Male              Dating
# 4      Yes        NaN      100 Level   18  Female              Single
# ..     ...        ...            ...  ...     ...                 ...
# 425    Yes        NaN      200 Level   20  Female              Single
# 426    Yes        NaN      200 Level   30    Male              Single
# 427    Yes        NaN      300 Level   21    Male              Single
# 428    Yes        NaN      100 Level   20  Female              Single
# 429    Yes        NaN      400 Level   22    Male              Single
#
#                     Faculty                                   Department  \
# 0               Engineering                         Chemical engineering
# 1               Engineering                         Chemical engineering
# 2               Engineering                         Chemical engineering
# 3           Social Sciences                            Political science
# 4               Engineering                         Computer engineering
# ..                      ...                                          ...
# 425      Management Science  Industrial relations & personnel management
# 426      Management Science                                   Accounting
# 427                Sciences                                      Physics
# 428  Basic Medical Sciences                   Medical laboratory science
# 429             Engineering                          Systems engineering
#
#                                          Strike_Effect  \
# 0    I learned how to study better and my grades al...
# 1    It affected it in a negative way as it became ...
# 2    It has actually helped me a bit. The extended ...
# 3                                                 Good
# 4                                                  NaN
# ..                                                 ...
# 425                                                NaN
# 426  It has really affect my service year,enlogated...
# 427                                    Business dey go
# 428                                                NaN
# 429                                                NaN
#
#                                       Challenging_Part  ...  \
# 0    Trying to remember things we were taught befor...  ...
# 1    Rekindling the student in me, lol. Trying to g...  ...
# 2                                 Readapting to school  ...
# 3                                             Reading   ...
# 4                                                  NaN  ...
# ..                                                 ...  ...
# 425                                                NaN  ...
# 426       It affected my grades,but all thanks to God.  ...
# 427                                           Reading   ...
# 428                                                NaN  ...
# 429                                                NaN  ...
#
#                                       Self_Development  \
# 0         Acquired skills unrelated to course of study
# 1         Acquired skills unrelated to course of study
# 2    Volunteered for an event or organization, Acqu...
# 3         Acquired skills unrelated to course of study
# 4    Volunteered for an event or organization, Acqu...
# ..                                                 ...
# 425  Acquired skills unrelated to course of study, ...
# 426        Acquired skills relevant to course of study
# 427       Acquired skills unrelated to course of study
# 428           Volunteered for an event or organization
# 429       Acquired skills unrelated to course of study
#
#     Exam_Prep_Before_Strike Exam_Prep_After_Strike  \
# 0                    Poorly                 Poorly
# 1                    Poorly             Moderately
# 2                Moderately             Moderately
# 3                Moderately                   Very
# 4                Moderately             Moderately
# ..                      ...                    ...
# 425              Moderately             Moderately
# 426              Moderately             Moderately
# 427                  Poorly             Moderately
# 428                  Poorly             Moderately
# 429                    Very                 Poorly
#
#                     Lectures_Affected  \
# 0                No noticeable change
# 1                No noticeable change
# 2    Fewer lecturers attended classes
# 3                No noticeable change
# 4    Fewer lecturers attended classes
# ..                                ...
# 425  Fewer lecturers attended classes
# 426  Fewer lecturers attended classes
# 427              No noticeable change
# 428              No noticeable change
# 429  Fewer lecturers attended classes
#
#                                    Academic_Activities Courses_Taken  \
# 0    Rarely: I engaged in academic activities once ...            10
# 1    Rarely: I engaged in academic activities once ...            10
# 2    Rarely: I engaged in academic activities once ...            10
# 3    Rarely: I engaged in academic activities once ...             7
# 4    Rarely: I engaged in academic activities once ...             8
# ..                                                 ...           ...
# 425  Sometimes: I engaged in academic activities oc...             6
# 426  Sometimes: I engaged in academic activities oc...             7
# 427  Never: I did not engage in any academic activi...             8
# 428  Often: I engaged in academic activities regula...             8
# 429  Never: I did not engage in any academic activi...            10
#
#      Course_Unit  CGPA_Before  CGPA_After  CGPA Change
# 0           23.0         3.39        3.51         0.12
# 1           23.0         4.44        4.50         0.06
# 2           23.0         3.54        3.61         0.07
# 3            NaN         3.86        3.96         0.10
# 4           18.0         0.00        4.28         4.28
# ..           ...          ...         ...          ...
# 425         22.0         4.03        4.33         0.30
# 426         18.0         4.56        4.56         0.00
# 427         22.0         3.69        3.47        -0.22
# 428          5.0         0.00        4.00         4.00
# 429         23.0         3.20        3.07        -0.13
#
# [413 rows x 21 columns]

# %%
df_unilag.drop(columns=['Non_Unilag'], inplace=True)
# Out:
# C:\Users\Modupe\AppData\Local\Temp\ipykernel_8028\948725449.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_unilag.drop(columns=['Non_Unilag'], inplace=True)

# %%
df_unilag.head(2)
# Out:
#   Unilag Academic_Level  Age  Gender Relationship_Status      Faculty  \
# 0    Yes      400 Level   22    Male              Single  Engineering
# 1    Yes      400 Level   23  Female              Single  Engineering
#
#              Department                                      Strike_Effect  \
# 0  Chemical engineering  I learned how to study better and my grades al...
# 1  Chemical engineering  It affected it in a negative way as it became ...
#
#                                     Challenging_Part  \
# 0  Trying to remember things we were taught befor...
# 1  Rekindling the student in me, lol. Trying to g...
#
#                             Job_Undertaken  \
# 0  Worked in a role relevant to my studies
# 1           Did not work during the strike
#
#                                Self_Development Exam_Prep_Before_Strike  \
# 0  Acquired skills unrelated to course of study                  Poorly
# 1  Acquired skills unrelated to course of study                  Poorly
#
#   Exam_Prep_After_Strike     Lectures_Affected  \
# 0                 Poorly  No noticeable change
# 1             Moderately  No noticeable change
#
#                                  Academic_Activities  Courses_Taken  \
# 0  Rarely: I engaged in academic activities once ...             10
# 1  Rarely: I engaged in academic activities once ...             10
#
#    Course_Unit  CGPA_Before  CGPA_After  CGPA Change
# 0         23.0         3.39        3.51         0.12
# 1         23.0         4.44        4.50         0.06

# %%
df_unilag = df_unilag[df_unilag['CGPA_After'] != 0]

# %%
#Extract a dataframe of individuals who had no cgpa before but cgpa after

no_cgpa_before = df_unilag[df_unilag['CGPA_Before'] == 0]

no_cgpa_before
# Out:
#     Unilag Academic_Level  Age  Gender Relationship_Status  \
# 4      Yes      100 Level   18  Female              Single
# 11     Yes      100 Level   20  Female              Single
# 17     Yes      100 Level   22  Female              Single
# 24     Yes      200 Level   20  Female              Single
# 26     Yes      100 Level   18  Female              Single
# ..     ...            ...  ...     ...                 ...
# 413    Yes      200 Level   25    Male              Single
# 418    Yes      200 Level   20  Female              Single
# 421    Yes      200 Level   20  Female              Single
# 423    Yes      100 Level   20    Male              Single
# 428    Yes      100 Level   20  Female              Single
#
#                     Faculty                     Department  \
# 4               Engineering           Computer engineering
# 11                 Sciences        Cell biology & genetics
# 17                 Sciences                 Marine science
# 24       Management Science                        Finance
# 26              Engineering         Biomedical engineering
# ..                      ...                            ...
# 413      Management Science        Business administration
# 418      Management Science                     Accounting
# 421      Management Science                     Accounting
# 423      Management Science  Actuarial science & insurance
# 428  Basic Medical Sciences     Medical laboratory science
#
#                                          Strike_Effect  \
# 4                                                  NaN
# 11   I find it hard to read sometimes when I hear r...
# 17                     It has been a draw back somehow
# 24   it has affected me badly. i got into this scho...
# 26                                        Not my best
# ..                                                 ...
# 413                                      Wasting time
# 418                                                NaN
# 421                                                NaN
# 423  It's fokin' delaying my education, like how ca...
# 428                                                NaN
#
#                                       Challenging_Part  \
# 4                                                  NaN
# 11   Reading and assimilating as I did before I lef...
# 17       Feels good but somehow cos it was a long time
# 24   the fact that i had to return back to school w...
# 26         Getting used to reading and studying again.
# ..                                                 ...
# 413                                                NaN
# 418                                                NaN
# 421                                  Trying to meet up
# 423  Most challenging part was how I'd cope, start ...
# 428                                                NaN
#
#                                Job_Undertaken  \
# 4     Worked in a role relevant to my studies
# 11   Worked in a role unrelated to my studies
# 17   Worked in a role unrelated to my studies
# 24             Did not work during the strike
# 26             Did not work during the strike
# ..                                        ...
# 413   Worked in a role relevant to my studies
# 418  Worked in a role unrelated to my studies
# 421            Did not work during the strike
# 423  Worked in a role unrelated to my studies
# 428   Worked in a role relevant to my studies
#
#                                       Self_Development  \
# 4    Volunteered for an event or organization, Acqu...
# 11                 Vocational training and artisanship
# 17        Acquired skills unrelated to course of study
# 24        Acquired skills unrelated to course of study
# 26                                   None of the above
# ..                                                 ...
# 413                                  None of the above
# 418  Vocational training and artisanship, None of t...
# 421                Vocational training and artisanship
# 423       Acquired skills unrelated to course of study
# 428           Volunteered for an event or organization
#
#     Exam_Prep_Before_Strike Exam_Prep_After_Strike  \
# 4                Moderately             Moderately
# 11                     Very             Moderately
# 17                   Poorly             Moderately
# 24               Moderately                 Poorly
# 26                   Poorly             Moderately
# ..                      ...                    ...
# 413              Moderately                 Poorly
# 418                  Poorly             Moderately
# 421                  Poorly             Moderately
# 423                  Poorly                   Very
# 428                  Poorly             Moderately
#
#                     Lectures_Affected  \
# 4    Fewer lecturers attended classes
# 11               No noticeable change
# 17   Fewer lecturers attended classes
# 24    Worse lectures after the strike
# 26               No noticeable change
# ..                                ...
# 413              No noticeable change
# 418  Fewer lecturers attended classes
# 421  Fewer lecturers attended classes
# 423              No noticeable change
# 428              No noticeable change
#
#                                    Academic_Activities  Courses_Taken  \
# 4    Rarely: I engaged in academic activities once ...              8
# 11   Rarely: I engaged in academic activities once ...              9
# 17   Rarely: I engaged in academic activities once ...              9
# 24   Never: I did not engage in any academic activi...              8
# 26   Rarely: I engaged in academic activities once ...              8
# ..                                                 ...            ...
# 413  Rarely: I engaged in academic activities once ...             10
# 418  Sometimes: I engaged in academic activities oc...              6
# 421  Sometimes: I engaged in academic activities oc...              9
# 423  Sometimes: I engaged in academic activities oc...              8
# 428  Often: I engaged in academic activities regula...              8
#
#      Course_Unit  CGPA_Before  CGPA_After  CGPA Change
# 4           18.0          0.0        4.28         4.28
# 11          21.0          0.0        3.10         3.10
# 17           NaN          0.0        3.30         3.30
# 24          20.0          0.0        2.34         2.34
# 26          20.0          0.0        3.81         3.81
# ..           ...          ...         ...          ...
# 413          5.0          0.0        4.89         4.89
# 418          NaN          0.0        3.50         3.50
# 421          NaN          0.0        5.00         5.00
# 423         19.0          0.0        4.27         4.27
# 428          5.0          0.0        4.00         4.00
#
# [77 rows x 20 columns]

# %%
df_unilag = df_unilag[df_unilag['CGPA_Before'] != 0.00]

# %%
#Checking data information
df_unilag.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 300 entries, 0 to 429
# Data columns (total 20 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Unilag                   300 non-null    object
#  1   Academic_Level           300 non-null    object
#  2   Age                      300 non-null    int64
#  3   Gender                   300 non-null    object
#  4   Relationship_Status      300 non-null    object
#  5   Faculty                  300 non-null    object
#  6   Department               300 non-null    object
#  7   Strike_Effect            244 non-null    object
#  8   Challenging_Part         241 non-null    object
#  9   Job_Undertaken           300 non-null    object
#  10  Self_Development         300 non-null    object
#  11  Exam_Prep_Before_Strike  300 non-null    object
#  12  Exam_Prep_After_Strike   300 non-null    object
#  13  Lectures_Affected        300 non-null    object
#  14  Academic_Activities      300 non-null    object
#  15  Courses_Taken            300 non-null    int64
#  16  Course_Unit              240 non-null    float64
#  17  CGPA_Before              300 non-null    float64
#  18  CGPA_After               300 non-null    float64
#  19  CGPA Change              300 non-null    float64
# dtypes: float64(4), int64(2), object(14)
# memory usage: 49.2+ KB

# %%
#Check missing values for each column, once more

df_unilag.isna().sum()
# Out:
# Unilag                      0
# Academic_Level              0
# Age                         0
# Gender                      0
# Relationship_Status         0
# Faculty                     0
# Department                  0
# Strike_Effect              56
# Challenging_Part           59
# Job_Undertaken              0
# Self_Development            0
# Exam_Prep_Before_Strike     0
# Exam_Prep_After_Strike      0
# Lectures_Affected           0
# Academic_Activities         0
# Courses_Taken               0
# Course_Unit                60
# CGPA_Before                 0
# CGPA_After                  0
# CGPA Change                 0
# dtype: int64

# %%
# Replace NaN values in the 'Strike_Effect' column with No Effect
df_unilag['Strike_Effect'].fillna(value='No effect', inplace=True)

# Replace NaN values in the 'Challenging_Part' column with No Challenge
df_unilag['Challenging_Part'].fillna(value='No challenge', inplace=True)

# %%
df_unilag.isna().sum()
# Out:
# Unilag                      0
# Academic_Level              0
# Age                         0
# Gender                      0
# Relationship_Status         0
# Faculty                     0
# Department                  0
# Strike_Effect               0
# Challenging_Part            0
# Job_Undertaken              0
# Self_Development            0
# Exam_Prep_Before_Strike     0
# Exam_Prep_After_Strike      0
# Lectures_Affected           0
# Academic_Activities         0
# Courses_Taken               0
# Course_Unit                60
# CGPA_Before                 0
# CGPA_After                  0
# CGPA Change                 0
# dtype: int64

# %%
df_unilag[df_unilag['Strike_Effect'] == 'No effect']
# Out:
#     Unilag Academic_Level  Age  Gender Relationship_Status  \
# 6      Yes      200 Level   20  Female              Single
# 29     Yes      300 Level   22  Female              Single
# 43     Yes      300 Level   21  Female              Single
# 51     Yes      200 Level   20    Male              Single
# 70     Yes      200 Level   21    Male              Single
# 83     Yes      200 Level   20    Male              Single
# 91     Yes      400 Level   26    Male              Single
# 92     Yes      300 Level   20  Female              Single
# 100    Yes      300 Level   21  Female              Single
# 101    Yes      300 Level   22    Male              Single
# 102    Yes      300 Level   21  Female              Single
# 106    Yes      400 Level   21    Male              Single
# 126    Yes      300 Level   20    Male              Single
# 142    Yes      300 Level   21    Male              Single
# 155    Yes      200 Level   19  Female              Single
# 163    Yes      200 Level   21    Male              Single
# 166    Yes      500 Level   25    Male              Single
# 193    Yes      300 Level   21    Male              Dating
# 203    Yes      200 Level   21    Male              Dating
# 209    Yes      200 Level   24    Male         Complicated
# 212    Yes      200 Level   22    Male              Single
# 242    Yes      400 Level   21    Male              Single
# 302    Yes      400 Level   27    Male              Single
# 310    Yes      500 Level   22    Male              Dating
# 312    Yes      300 Level   22  Female              Single
# 314    Yes      300 Level   21  Female              Single
# 316    Yes      300 Level   20    Male              Dating
# 317    Yes      300 Level   25  Female              Single
# 324    Yes      300 Level   22  Female              Single
# 326    Yes      500 Level   25  Female              Single
# 327    Yes      300 Level   20  Female              Dating
# 328    Yes      200 Level   20  Female              Single
# 329    Yes      400 Level   22  Female              Single
# 330    Yes      300 Level   22  Female              Dating
# 334    Yes      400 Level   21  Female              Single
# 336    Yes      200 Level   20    Male              Single
# 337    Yes      300 Level   21    Male              Single
# 339    Yes      200 Level   21  Female              Dating
# 341    Yes      400 Level   22  Female              Single
# 357    Yes      200 Level   22    Male              Single
# 365    Yes      400 Level   22  Female              Single
# 367    Yes      400 Level   23  Female              Single
# 370    Yes      300 Level   21    Male              Single
# 384    Yes      400 Level   22    Male              Single
# 386    Yes      200 Level   22    Male         Complicated
# 390    Yes      200 Level   20    Male              Single
# 394    Yes      400 Level   25    Male              Single
# 396    Yes      200 Level   25    Male              Single
# 398    Yes      400 Level   23    Male              Single
# 404    Yes      300 Level   29    Male              Single
# 406    Yes      400 Level   22    Male              Single
# 411    Yes      200 Level   24    Male              Dating
# 414    Yes      200 Level   20    Male              Single
# 422    Yes      200 Level   21    Male              Single
# 425    Yes      200 Level   20  Female              Single
# 429    Yes      400 Level   22    Male              Single
#
#                     Faculty                                   Department  \
# 6                  Sciences                                   Statistics
# 29          Social Sciences                           Mass communication
# 43                Education                      Science tech. education
# 51                 Pharmacy                                     Pharmacy
# 70       Management Science                                      Finance
# 83                 Sciences                      Biochemistry (sciences)
# 91       Management Science                                      Finance
# 92              Engineering                          Systems engineering
# 100                Sciences                                      Zoology
# 101                Sciences                                      Zoology
# 102                Sciences                      Cell biology & genetics
# 106         Social Sciences                           Mass communication
# 126             Engineering                         Chemical engineering
# 142             Engineering                          Systems engineering
# 155             Engineering                          Systems engineering
# 163                Sciences                                   Statistics
# 166             Engineering                       Mechanical engineering
# 193             Engineering                          Systems engineering
# 203                Sciences                      Cell biology & genetics
# 209                Sciences                                   Statistics
# 212                Sciences                      Cell biology & genetics
# 242         Social Sciences                           Mass communication
# 302      Management Science                Actuarial science & insurance
# 310                Sciences                            Computer sciences
# 312                Sciences                      Biochemistry (sciences)
# 314                Sciences                      Cell biology & genetics
# 316                Sciences                      Cell biology & genetics
# 317                Sciences                                      Zoology
# 324  Basic Medical Sciences                                 Pharmacology
# 326                Sciences                               Marine science
# 327                     Law                                          Law
# 328             Engineering                         Chemical engineering
# 329                Pharmacy                                    Pharmacy
# 330      Management Science                      Business administration
# 334             Engineering                       Mechanical engineering
# 336                Sciences                                  Mathematics
# 337               Education                                  Mathematics
# 339      Management Science                                   Accounting
# 341      Management Science                                      Finance
# 357         Dental Sciences                        Restorative dentistry
# 365                    Arts                                   Philosophy
# 367               Education                     Education administration
# 370                Sciences                      Biochemistry (sciences)
# 384      Management Science                Actuarial science & insurance
# 386             Engineering                       Mechanical engineering
# 390                Sciences                                  Geosciences
# 394                    Arts                                      English
# 396                    Arts                                   Philosophy
# 398      Management Science                Actuarial science & insurance
# 404               Education              Arts & social science education
# 406      Management Science                Actuarial science & insurance
# 411      Management Science                                   Accounting
# 414      Management Science                                   Accounting
# 422      Management Science                                   Accounting
# 425      Management Science  Industrial relations & personnel management
# 429             Engineering                          Systems engineering
#
#     Strike_Effect                                   Challenging_Part  \
# 6       No effect                                       No challenge
# 29      No effect                                       No challenge
# 43      No effect                                       No challenge
# 51      No effect                                       No challenge
# 70      No effect                                       No challenge
# 83      No effect                                       No challenge
# 91      No effect                                       No challenge
# 92      No effect                Catching up with school's learning
# 100     No effect                     Becoming fond of school again
# 101     No effect                                       No challenge
# 102     No effect  I had difficult time going back to my books. A...
# 106     No effect                                       No challenge
# 126     No effect                                       No challenge
# 142     No effect                                       No challenge
# 155     No effect                                       No challenge
# 163     No effect                                       No challenge
# 166     No effect                                       No challenge
# 193     No effect                                       No challenge
# 203     No effect                         Reading and managing work
# 209     No effect                                       No challenge
# 212     No effect                                       No challenge
# 242     No effect                                       No challenge
# 302     No effect                                       No challenge
# 310     No effect                                       No challenge
# 312     No effect                                       No challenge
# 314     No effect                                       No challenge
# 316     No effect                                       No challenge
# 317     No effect                                           Reading
# 324     No effect  What was learnt before the strike looking stra...
# 326     No effect                                       No challenge
# 327     No effect                                       No challenge
# 328     No effect                                       No challenge
# 329     No effect                                       No challenge
# 330     No effect                                       No challenge
# 334     No effect                                       No challenge
# 336     No effect                                       No challenge
# 337     No effect                                       No challenge
# 339     No effect                                       No challenge
# 341     No effect                                       No challenge
# 357     No effect                                       No challenge
# 365     No effect                                       No challenge
# 367     No effect                                       No challenge
# 370     No effect                                       No challenge
# 384     No effect                                       No challenge
# 386     No effect                                       No challenge
# 390     No effect                                       No challenge
# 394     No effect                   I have work I have to sacrifice
# 396     No effect                                       No challenge
# 398     No effect                                       No challenge
# 404     No effect  The most challenging part is awaken the brain ...
# 406     No effect                                       No challenge
# 411     No effect                                       No challenge
# 414     No effect                                       No challenge
# 422     No effect                                       No challenge
# 425     No effect                                       No challenge
# 429     No effect                                       No challenge
#
#                                Job_Undertaken  \
# 6    Worked in a role unrelated to my studies
# 29   Worked in a role unrelated to my studies
# 43   Worked in a role unrelated to my studies
# 51   Worked in a role unrelated to my studies
# 70    Worked in a role relevant to my studies
# 83             Did not work during the strike
# 91    Worked in a role relevant to my studies
# 92   Worked in a role unrelated to my studies
# 100            Did not work during the strike
# 101  Worked in a role unrelated to my studies
# 102  Worked in a role unrelated to my studies
# 106   Worked in a role relevant to my studies
# 126            Did not work during the strike
# 142  Worked in a role unrelated to my studies
# 155            Did not work during the strike
# 163  Worked in a role unrelated to my studies
# 166   Worked in a role relevant to my studies
# 193  Worked in a role unrelated to my studies
# 203  Worked in a role unrelated to my studies
# 209  Worked in a role unrelated to my studies
# 212  Worked in a role unrelated to my studies
# 242   Worked in a role relevant to my studies
# 302  Worked in a role unrelated to my studies
# 310   Worked in a role relevant to my studies
# 312            Did not work during the strike
# 314  Worked in a role unrelated to my studies
# 316            Did not work during the strike
# 317  Worked in a role unrelated to my studies
# 324  Worked in a role unrelated to my studies
# 326   Worked in a role relevant to my studies
# 327  Worked in a role unrelated to my studies
# 328  Worked in a role unrelated to my studies
# 329            Did not work during the strike
# 330   Worked in a role relevant to my studies
# 334            Did not work during the strike
# 336  Worked in a role unrelated to my studies
# 337  Worked in a role unrelated to my studies
# 339  Worked in a role unrelated to my studies
# 341  Worked in a role unrelated to my studies
# 357            Did not work during the strike
# 365            Did not work during the strike
# 367  Worked in a role unrelated to my studies
# 370            Did not work during the strike
# 384  Worked in a role unrelated to my studies
# 386  Worked in a role unrelated to my studies
# 390            Did not work during the strike
# 394  Worked in a role unrelated to my studies
# 396  Worked in a role unrelated to my studies
# 398  Worked in a role unrelated to my studies
# 404  Worked in a role unrelated to my studies
# 406            Did not work during the strike
# 411   Worked in a role relevant to my studies
# 414  Worked in a role unrelated to my studies
# 422            Did not work during the strike
# 425  Worked in a role unrelated to my studies
# 429  Worked in a role unrelated to my studies
#
#                                       Self_Development  \
# 6         Acquired skills unrelated to course of study
# 29        Acquired skills unrelated to course of study
# 43                 Vocational training and artisanship
# 51        Acquired skills unrelated to course of study
# 70         Acquired skills relevant to course of study
# 83        Acquired skills unrelated to course of study
# 91         Acquired skills relevant to course of study
# 92         Acquired skills relevant to course of study
# 100  Acquired skills relevant to course of study, A...
# 101       Acquired skills unrelated to course of study
# 102  Acquired skills unrelated to course of study, ...
# 106  Acquired skills relevant to course of study, A...
# 126       Acquired skills unrelated to course of study
# 142  Acquired skills relevant to course of study, A...
# 155                Vocational training and artisanship
# 163       Acquired skills unrelated to course of study
# 166  Volunteered for an event or organization, Acqu...
# 193  Volunteered for an event or organization, Acqu...
# 203       Acquired skills unrelated to course of study
# 209  Acquired skills relevant to course of study, A...
# 212  Acquired skills unrelated to course of study, ...
# 242  Acquired skills relevant to course of study, A...
# 302        Acquired skills relevant to course of study
# 310        Acquired skills relevant to course of study
# 312                                  None of the above
# 314                Vocational training and artisanship
# 316  Acquired skills relevant to course of study, A...
# 317  Acquired skills unrelated to course of study, ...
# 324       Acquired skills unrelated to course of study
# 326  Volunteered for an event or organization, Acqu...
# 327                                  None of the above
# 328       Acquired skills unrelated to course of study
# 329  Acquired skills relevant to course of study, V...
# 330  Volunteered for an event or organization, Acqu...
# 334       Acquired skills unrelated to course of study
# 336                                  None of the above
# 337       Acquired skills unrelated to course of study
# 339  Acquired skills relevant to course of study, A...
# 341                Vocational training and artisanship
# 357       Acquired skills unrelated to course of study
# 365                                  None of the above
# 367  Acquired skills relevant to course of study, A...
# 370                                  None of the above
# 384       Acquired skills unrelated to course of study
# 386  Acquired skills relevant to course of study, A...
# 390        Acquired skills relevant to course of study
# 394                                  None of the above
# 396  Acquired skills unrelated to course of study, ...
# 398       Acquired skills unrelated to course of study
# 404                Vocational training and artisanship
# 406        Acquired skills relevant to course of study
# 411                Vocational training and artisanship
# 414       Acquired skills unrelated to course of study
# 422                                  None of the above
# 425  Acquired skills unrelated to course of study, ...
# 429       Acquired skills unrelated to course of study
#
#     Exam_Prep_Before_Strike Exam_Prep_After_Strike  \
# 6                Moderately             Moderately
# 29                   Poorly             Moderately
# 43                   Poorly             Moderately
# 51               Moderately             Moderately
# 70                     Very             Moderately
# 83                   Poorly             Moderately
# 91               Moderately                 Poorly
# 92                     Very             Moderately
# 100                  Poorly             Moderately
# 101              Moderately             Moderately
# 102              Moderately                 Poorly
# 106              Moderately             Moderately
# 126                  Poorly             Moderately
# 142              Moderately             Moderately
# 155                  Poorly             Moderately
# 163              Moderately             Moderately
# 166                    Very             Moderately
# 193              Moderately                 Poorly
# 203              Moderately             Moderately
# 209                    Very                 Poorly
# 212              Moderately                 Poorly
# 242              Moderately             Moderately
# 302              Moderately                   Very
# 310                  Poorly             Moderately
# 312              Moderately                 Poorly
# 314              Moderately                   Very
# 316              Moderately             Moderately
# 317                  Poorly                   Very
# 324                    Very             Moderately
# 326              Moderately                 Poorly
# 327              Moderately             Moderately
# 328                    Very             Moderately
# 329              Moderately                 Poorly
# 330                  Poorly                 Poorly
# 334              Moderately                   Very
# 336                  Poorly                 Poorly
# 337                  Poorly                 Poorly
# 339                    Very                 Poorly
# 341              Moderately             Moderately
# 357                  Poorly             Moderately
# 365                    Very                 Poorly
# 367              Moderately                 Poorly
# 370              Moderately                 Poorly
# 384                  Poorly             Moderately
# 386              Moderately             Moderately
# 390              Moderately             Moderately
# 394                    Very             Moderately
# 396              Moderately                 Poorly
# 398                    Very             Moderately
# 404                    Very             Moderately
# 406              Moderately                 Poorly
# 411                    Very             Moderately
# 414                    Very             Moderately
# 422              Moderately             Moderately
# 425              Moderately             Moderately
# 429                    Very                 Poorly
#
#                                   Lectures_Affected  \
# 6                              No noticeable change
# 29                  Worse lectures after the strike
# 43   I did not attend any lectures after the strike
# 51                 Fewer lecturers attended classes
# 70                 Fewer lecturers attended classes
# 83                  Worse lectures after the strike
# 91                  Worse lectures after the strike
# 92                 Fewer lecturers attended classes
# 100                Fewer lecturers attended classes
# 101                            No noticeable change
# 102                 Worse lectures after the strike
# 106                            No noticeable change
# 126                 Worse lectures after the strike
# 142                            No noticeable change
# 155                            No noticeable change
# 163  I did not attend any lectures after the strike
# 166                            No noticeable change
# 193                            No noticeable change
# 203                            No noticeable change
# 209                 Worse lectures after the strike
# 212                 Worse lectures after the strike
# 242              Improved lectures after the strike
# 302                            No noticeable change
# 310                 Worse lectures after the strike
# 312                            No noticeable change
# 314                 Worse lectures after the strike
# 316              Improved lectures after the strike
# 317                Fewer lecturers attended classes
# 324              Improved lectures after the strike
# 326                Fewer lecturers attended classes
# 327                 Worse lectures after the strike
# 328                 Worse lectures after the strike
# 329                 Worse lectures after the strike
# 330                Fewer lecturers attended classes
# 334                 Worse lectures after the strike
# 336                            No noticeable change
# 337                Fewer lecturers attended classes
# 339  I did not attend any lectures after the strike
# 341                            No noticeable change
# 357                 Worse lectures after the strike
# 365                 Worse lectures after the strike
# 367                            No noticeable change
# 370                 Worse lectures after the strike
# 384                Fewer lecturers attended classes
# 386                 Worse lectures after the strike
# 390                            No noticeable change
# 394                Fewer lecturers attended classes
# 396                 Worse lectures after the strike
# 398                Fewer lecturers attended classes
# 404              Improved lectures after the strike
# 406                 Worse lectures after the strike
# 411                            No noticeable change
# 414                Fewer lecturers attended classes
# 422                Fewer lecturers attended classes
# 425                Fewer lecturers attended classes
# 429                Fewer lecturers attended classes
#
#                                    Academic_Activities  Courses_Taken  \
# 6    Rarely: I engaged in academic activities once ...              5
# 29   Sometimes: I engaged in academic activities oc...              9
# 43   Never: I did not engage in any academic activi...              7
# 51   Often: I engaged in academic activities regula...              7
# 70   Rarely: I engaged in academic activities once ...              7
# 83   Sometimes: I engaged in academic activities oc...              9
# 91   Never: I did not engage in any academic activi...              8
# 92   Never: I did not engage in any academic activi...             10
# 100  Rarely: I engaged in academic activities once ...              6
# 101  Never: I did not engage in any academic activi...              5
# 102  Rarely: I engaged in academic activities once ...              6
# 106  Sometimes: I engaged in academic activities oc...              7
# 126  Never: I did not engage in any academic activi...              9
# 142  Often: I engaged in academic activities regula...             10
# 155  Never: I did not engage in any academic activi...             10
# 163  Never: I did not engage in any academic activi...              6
# 166  Often: I engaged in academic activities regula...              8
# 193  Sometimes: I engaged in academic activities oc...             10
# 203  Rarely: I engaged in academic activities once ...              6
# 209  Rarely: I engaged in academic activities once ...              5
# 212  Never: I did not engage in any academic activi...              6
# 242  Sometimes: I engaged in academic activities oc...              7
# 302  Rarely: I engaged in academic activities once ...              8
# 310  Sometimes: I engaged in academic activities oc...              3
# 312  Never: I did not engage in any academic activi...              7
# 314  Rarely: I engaged in academic activities once ...              7
# 316  Sometimes: I engaged in academic activities oc...              8
# 317  Never: I did not engage in any academic activi...              6
# 324  Sometimes: I engaged in academic activities oc...              8
# 326  Rarely: I engaged in academic activities once ...              4
# 327  Rarely: I engaged in academic activities once ...              5
# 328  Sometimes: I engaged in academic activities oc...             10
# 329  Very often: I engaged in academic activities a...             12
# 330  Never: I did not engage in any academic activi...              8
# 334  Often: I engaged in academic activities regula...              8
# 336  Rarely: I engaged in academic activities once ...              7
# 337  Very often: I engaged in academic activities a...              7
# 339  Never: I did not engage in any academic activi...              8
# 341  Sometimes: I engaged in academic activities oc...              7
# 357  Rarely: I engaged in academic activities once ...              3
# 365  Never: I did not engage in any academic activi...              9
# 367  Sometimes: I engaged in academic activities oc...              7
# 370  Often: I engaged in academic activities regula...              7
# 384  Never: I did not engage in any academic activi...              7
# 386  Often: I engaged in academic activities regula...             11
# 390  Often: I engaged in academic activities regula...              8
# 394  Rarely: I engaged in academic activities once ...             10
# 396  Never: I did not engage in any academic activi...              9
# 398  Sometimes: I engaged in academic activities oc...              7
# 404  Rarely: I engaged in academic activities once ...              9
# 406  Sometimes: I engaged in academic activities oc...              8
# 411  Rarely: I engaged in academic activities once ...              8
# 414  Never: I did not engage in any academic activi...              9
# 422  Sometimes: I engaged in academic activities oc...              9
# 425  Sometimes: I engaged in academic activities oc...              6
# 429  Never: I did not engage in any academic activi...             10
#
#      Course_Unit  CGPA_Before  CGPA_After  CGPA Change
# 6           15.0         4.00        3.80        -0.20
# 29           NaN         4.10        3.90        -0.20
# 43          16.0         2.77        2.80         0.03
# 51          18.0         5.00        4.89        -0.11
# 70           0.0         4.00        3.99        -0.01
# 83          21.0         3.00        3.00         0.00
# 91          22.0         4.30        4.00        -0.30
# 92          17.0         3.79        3.88         0.09
# 100          NaN         3.40        3.89         0.49
# 101          NaN         2.98        3.22         0.24
# 102          NaN         3.82        3.82         0.00
# 106          NaN         3.59        3.59         0.00
# 126          NaN         4.47        4.44        -0.03
# 142          NaN         4.45        4.40        -0.05
# 155         28.0         4.00        3.14        -0.86
# 163          NaN         3.00        3.50         0.50
# 166          NaN         4.52        4.55         0.03
# 193         22.0         2.90        2.00        -0.90
# 203         19.0         4.16        4.28         0.12
# 209         16.0         3.80        3.50        -0.30
# 212          NaN         3.22        3.40         0.18
# 242         19.0         3.47        3.67         0.20
# 302          NaN         3.03        3.14         0.11
# 310          9.0         3.93        4.04         0.11
# 312          NaN         3.87        3.40        -0.47
# 314          NaN         4.88        4.92         0.04
# 316         20.0         2.88        4.20         1.32
# 317          NaN         2.70        3.10         0.40
# 324          NaN         4.26        4.35         0.09
# 326         12.0         4.00        3.90        -0.10
# 327         20.0         3.97        4.20         0.23
# 328         21.0         4.00        4.00         0.00
# 329          NaN         3.80        3.60        -0.20
# 330         20.0         4.56        4.64         0.08
# 334         19.0         4.04        4.08         0.04
# 336          NaN         2.80        2.06        -0.74
# 337          NaN         3.49        3.32        -0.17
# 339          0.0         4.10        4.10         0.00
# 341         22.0         3.63        3.70         0.07
# 357          9.0         3.94        3.94         0.00
# 365         18.0         4.10        4.13         0.03
# 367          NaN         3.60        3.30        -0.30
# 370          0.0         3.50        3.00        -0.50
# 384         18.0         3.30        3.40         0.10
# 386         22.0         4.30        4.30         0.00
# 390         20.0         4.60        4.60         0.00
# 394         20.0         3.60        3.50        -0.10
# 396          NaN         4.00        3.00        -1.00
# 398         18.0         3.46        3.33        -0.13
# 404          5.0         3.00        3.09         0.09
# 406         18.0         4.46        4.54         0.08
# 411          NaN         4.25        4.17        -0.08
# 414         20.0         4.80        4.60        -0.20
# 422         23.0         4.00        4.00         0.00
# 425         22.0         4.03        4.33         0.30
# 429         23.0         3.20        3.07        -0.13

# %% [markdown]
# ### Quest for Duplicates

# %%
#Search for duplicates

df_unilag[df_unilag.duplicated()]
# Out:
#     Unilag Academic_Level  Age  Gender Relationship_Status    Faculty  \
# 160    Yes      400 Level   22  Female              Single  Education
#
#                           Department                   Strike_Effect  \
# 160  Arts & social science education  I just want to end all this..🥲
#
#                                       Challenging_Part  \
# 160  Having to return back to reading books and att...
#
#                                Job_Undertaken  \
# 160  Worked in a role unrelated to my studies
#
#                                       Self_Development  \
# 160  Acquired skills unrelated to course of study, ...
#
#     Exam_Prep_Before_Strike Exam_Prep_After_Strike     Lectures_Affected  \
# 160              Moderately                 Poorly  No noticeable change
#
#                                    Academic_Activities  Courses_Taken  \
# 160  Never: I did not engage in any academic activi...              8
#
#      Course_Unit  CGPA_Before  CGPA_After  CGPA Change
# 160         16.0         3.69        2.34        -1.35

# %%
df_unilag[df_unilag['Strike_Effect'] == "I just want to end all this..🥲"]
# Out:
#     Unilag Academic_Level  Age  Gender Relationship_Status    Faculty  \
# 156    Yes      400 Level   22  Female              Single  Education
# 160    Yes      400 Level   22  Female              Single  Education
#
#                           Department                   Strike_Effect  \
# 156  Arts & social science education  I just want to end all this..🥲
# 160  Arts & social science education  I just want to end all this..🥲
#
#                                       Challenging_Part  \
# 156  Having to return back to reading books and att...
# 160  Having to return back to reading books and att...
#
#                                Job_Undertaken  \
# 156  Worked in a role unrelated to my studies
# 160  Worked in a role unrelated to my studies
#
#                                       Self_Development  \
# 156  Acquired skills unrelated to course of study, ...
# 160  Acquired skills unrelated to course of study, ...
#
#     Exam_Prep_Before_Strike Exam_Prep_After_Strike     Lectures_Affected  \
# 156              Moderately                 Poorly  No noticeable change
# 160              Moderately                 Poorly  No noticeable change
#
#                                    Academic_Activities  Courses_Taken  \
# 156  Never: I did not engage in any academic activi...              8
# 160  Never: I did not engage in any academic activi...              8
#
#      Course_Unit  CGPA_Before  CGPA_After  CGPA Change
# 156         16.0         3.69        2.34        -1.35
# 160         16.0         3.69        2.34        -1.35

# %%
df_unilag.drop_duplicates(keep='first', inplace=True)
df_unilag.reset_index(drop=True, inplace = True)

df_unilag
# Out:
#     Unilag Academic_Level  Age  Gender Relationship_Status  \
# 0      Yes      400 Level   22    Male              Single
# 1      Yes      400 Level   23  Female              Single
# 2      Yes      400 Level   21    Male              Dating
# 3      Yes      400 Level   29    Male              Dating
# 4      Yes      300 Level   24    Male              Single
# ..     ...            ...  ...     ...                 ...
# 294    Yes      200 Level   25  Female              Single
# 295    Yes      200 Level   20  Female              Single
# 296    Yes      200 Level   30    Male              Single
# 297    Yes      300 Level   21    Male              Single
# 298    Yes      400 Level   22    Male              Single
#
#                 Faculty                                   Department  \
# 0           Engineering                         Chemical engineering
# 1           Engineering                         Chemical engineering
# 2           Engineering                         Chemical engineering
# 3       Social Sciences                            Political science
# 4             Education                      Educational foundations
# ..                  ...                                          ...
# 294  Management Science                                   Accounting
# 295  Management Science  Industrial relations & personnel management
# 296  Management Science                                   Accounting
# 297            Sciences                                      Physics
# 298         Engineering                          Systems engineering
#
#                                          Strike_Effect  \
# 0    I learned how to study better and my grades al...
# 1    It affected it in a negative way as it became ...
# 2    It has actually helped me a bit. The extended ...
# 3                                                 Good
# 4             Reluctance to concentrate on my studies
# ..                                                 ...
# 294  The ASUU strike has greatly contributed to dem...
# 295                                          No effect
# 296  It has really affect my service year,enlogated...
# 297                                    Business dey go
# 298                                          No effect
#
#                                       Challenging_Part  \
# 0    Trying to remember things we were taught befor...
# 1    Rekindling the student in me, lol. Trying to g...
# 2                                 Readapting to school
# 3                                             Reading
# 4         Getting to dust my books and and assimilate
# ..                                                 ...
# 294  The disorientation in the sense that the manag...
# 295                                       No challenge
# 296       It affected my grades,but all thanks to God.
# 297                                           Reading
# 298                                       No challenge
#
#                                Job_Undertaken  \
# 0     Worked in a role relevant to my studies
# 1              Did not work during the strike
# 2    Worked in a role unrelated to my studies
# 3    Worked in a role unrelated to my studies
# 4              Did not work during the strike
# ..                                        ...
# 294  Worked in a role unrelated to my studies
# 295  Worked in a role unrelated to my studies
# 296   Worked in a role relevant to my studies
# 297  Worked in a role unrelated to my studies
# 298  Worked in a role unrelated to my studies
#
#                                       Self_Development  \
# 0         Acquired skills unrelated to course of study
# 1         Acquired skills unrelated to course of study
# 2    Volunteered for an event or organization, Acqu...
# 3         Acquired skills unrelated to course of study
# 4                                    None of the above
# ..                                                 ...
# 294  Acquired skills relevant to course of study, A...
# 295  Acquired skills unrelated to course of study, ...
# 296        Acquired skills relevant to course of study
# 297       Acquired skills unrelated to course of study
# 298       Acquired skills unrelated to course of study
#
#     Exam_Prep_Before_Strike Exam_Prep_After_Strike  \
# 0                    Poorly                 Poorly
# 1                    Poorly             Moderately
# 2                Moderately             Moderately
# 3                Moderately                   Very
# 4                    Poorly                   Very
# ..                      ...                    ...
# 294              Moderately             Moderately
# 295              Moderately             Moderately
# 296              Moderately             Moderately
# 297                  Poorly             Moderately
# 298                    Very                 Poorly
#
#                     Lectures_Affected  \
# 0                No noticeable change
# 1                No noticeable change
# 2    Fewer lecturers attended classes
# 3                No noticeable change
# 4     Worse lectures after the strike
# ..                                ...
# 294              No noticeable change
# 295  Fewer lecturers attended classes
# 296  Fewer lecturers attended classes
# 297              No noticeable change
# 298  Fewer lecturers attended classes
#
#                                    Academic_Activities  Courses_Taken  \
# 0    Rarely: I engaged in academic activities once ...             10
# 1    Rarely: I engaged in academic activities once ...             10
# 2    Rarely: I engaged in academic activities once ...             10
# 3    Rarely: I engaged in academic activities once ...              7
# 4    Never: I did not engage in any academic activi...              9
# ..                                                 ...            ...
# 294  Sometimes: I engaged in academic activities oc...              7
# 295  Sometimes: I engaged in academic activities oc...              6
# 296  Sometimes: I engaged in academic activities oc...              7
# 297  Never: I did not engage in any academic activi...              8
# 298  Never: I did not engage in any academic activi...             10
#
#      Course_Unit  CGPA_Before  CGPA_After  CGPA Change
# 0           23.0         3.39        3.51         0.12
# 1           23.0         4.44        4.50         0.06
# 2           23.0         3.54        3.61         0.07
# 3            NaN         3.86        3.96         0.10
# 4           18.0         2.85        2.00        -0.85
# ..           ...          ...         ...          ...
# 294         14.0         3.70        2.90        -0.80
# 295         22.0         4.03        4.33         0.30
# 296         18.0         4.56        4.56         0.00
# 297         22.0         3.69        3.47        -0.22
# 298         23.0         3.20        3.07        -0.13
#
# [299 rows x 20 columns]

# %% [markdown]
# ## It is clear that 75 missing values in a column is wild.
#
# The safest option is to create a simple model to predict the values

# %%
col_list = df_unilag.columns.tolist()

print(col_list, end = '')
# Out:
# ['Unilag', 'Academic_Level', 'Age', 'Gender', 'Relationship_Status', 'Faculty', 'Department', 'Strike_Effect', 'Challenging_Part', 'Job_Undertaken', 'Self_Development', 'Exam_Prep_Before_Strike', 'Exam_Prep_After_Strike', 'Lectures_Affected', 'Academic_Activities', 'Courses_Taken', 'Course_Unit', 'CGPA_Before', 'CGPA_After', 'CGPA Change']

# %%
#Drop columns

columns_to_drop = ['Strike_Effect', 'Challenging_Part', 'Job_Undertaken', 'Self_Development', 'Exam_Prep_Before_Strike', 
                   'Exam_Prep_After_Strike', 'Lectures_Affected', 'Academic_Activities','Relationship_Status', 'Age', "Gender",
                   'CGPA_Before', 'CGPA_After', 'CGPA Change']
missing_course_units  = df_unilag.drop(columns_to_drop, axis=1)

# %%
missing_course_units.head(2)
# Out:
#   Unilag Academic_Level      Faculty            Department  Courses_Taken  \
# 0    Yes      400 Level  Engineering  Chemical engineering             10
# 1    Yes      400 Level  Engineering  Chemical engineering             10
#
#    Course_Unit
# 0         23.0
# 1         23.0

# %%
missing_course_units.isna().sum()
# Out:
# Unilag             0
# Academic_Level     0
# Faculty            0
# Department         0
# Courses_Taken      0
# Course_Unit       60
# dtype: int64

# %%
len(missing_course_units)
# Out:
# 299

# %%
missing_course_units['Course_Unit'].fillna(0, inplace=True)

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# Step 1: Prepare the data

test_data = missing_course_units[missing_course_units['Course_Unit'].notnull() & (missing_course_units['Course_Unit'] > 0)].reset_index(drop=True)

# Create a DataFrame with missing values for 'course unit per semester' (training data)
training_data = missing_course_units[missing_course_units['Course_Unit'] == 0].reset_index(drop=True)


# Step 2: Split the data into features (X) and target (y)

X_test = test_data.drop(columns=['Course_Unit'])
y_test = test_data['Course_Unit']

# %%
test_data.head(50)
# Out:
#    Unilag Academic_Level                 Faculty  \
# 0     Yes      400 Level             Engineering
# 1     Yes      400 Level             Engineering
# 2     Yes      400 Level             Engineering
# 3     Yes      300 Level               Education
# 4     Yes      200 Level                Sciences
# 5     Yes      300 Level                Sciences
# 6     Yes      400 Level             Engineering
# 7     Yes      300 Level               Education
# 8     Yes      400 Level      Management Science
# 9     Yes      400 Level                Sciences
# 10    Yes      400 Level      Management Science
# 11    Yes      500 Level             Engineering
# 12    Yes      400 Level             Engineering
# 13    Yes      400 Level  Environmental Sciences
# 14    Yes      300 Level                Sciences
# 15    Yes      400 Level                     Law
# 16    Yes      400 Level             Engineering
# 17    Yes      400 Level             Engineering
# 18    Yes      300 Level               Education
# 19    Yes      300 Level                Sciences
# 20    Yes      200 Level      Management Science
# 21    Yes      500 Level                     Law
# 22    Yes      300 Level               Education
# 23    Yes      300 Level                Sciences
# 24    Yes      300 Level               Education
# 25    Yes      300 Level                Sciences
# 26    Yes      300 Level                Sciences
# 27    Yes      300 Level                Sciences
# 28    Yes      200 Level                Pharmacy
# 29    Yes      300 Level               Education
# 30    Yes      500 Level                     Law
# 31    Yes      400 Level             Engineering
# 32    Yes      300 Level                Sciences
# 33    Yes      300 Level                Sciences
# 34    Yes      300 Level      Management Science
# 35    Yes      200 Level                Sciences
# 36    Yes      400 Level             Engineering
# 37    Yes      300 Level                     Law
# 38    Yes      300 Level                     Law
# 39    Yes      300 Level      Management Science
# 40    Yes      300 Level               Education
# 41    Yes      200 Level             Engineering
# 42    Yes      200 Level             Engineering
# 43    Yes      400 Level                Sciences
# 44    Yes      300 Level                Sciences
# 45    Yes      200 Level                Sciences
# 46    Yes      200 Level                Sciences
# 47    Yes      400 Level             Engineering
# 48    Yes      200 Level         Social Sciences
# 49    Yes      100 Level                Sciences
#
#                                      Department  Courses_Taken  Course_Unit
# 0                          Chemical engineering             10         23.0
# 1                          Chemical engineering             10         23.0
# 2                          Chemical engineering             10         23.0
# 3                       Educational foundations              9         18.0
# 4                                    Statistics              5         15.0
# 5                                   Geosciences             10         21.0
# 6                   Petroleum & gas engineering             10         21.0
# 7                       Educational foundations             10         20.0
# 8                                       Finance              7          5.0
# 9                                Marine science              3          9.0
# 10  Industrial relations & personnel management              6         16.0
# 11                       Mechanical engineering              8         21.0
# 12                         Computer engineering             11         20.0
# 13                                       Estate              7         15.0
# 14        Biochemistry (basic medical sciences)              9         20.0
# 15                                          Law              5         20.0
# 16                         Chemical engineering             10         23.0
# 17                       Mechanical engineering              8          8.0
# 18              Arts & social science education             11         24.0
# 19                                      Zoology              8         21.0
# 20                                      Finance              7         21.0
# 21                                          Law              5         20.0
# 22                      Science tech. education              7         16.0
# 23                      Biochemistry (sciences)              8         16.0
# 24                     Education administration              8         25.0
# 25                                       Botany              6         17.0
# 26                      Cell biology & genetics              6         18.0
# 27                               Marine science              8         20.0
# 28                                     Pharmacy              7         18.0
# 29                       Education and biology               8         18.0
# 30                                         Law               6         24.0
# 31                         Chemical engineering             10         23.0
# 32                                       Botany              7         17.0
# 33                                       Botany              5         16.0
# 34                                   Accounting              9         23.0
# 35                                       Botany              6         12.0
# 36                         Chemical engineering             10         23.0
# 37                                          Law              6         22.0
# 38                                          Law              5         20.0
# 39                                      Finance              7         22.0
# 40                      Educational foundations              8         16.0
# 41                         Chemical engineering             10         21.0
# 42                         Chemical engineering             10         23.0
# 43                                      Physics              6         12.0
# 44                               Marine science              7         21.0
# 45                                       Botany              7          0.1
# 46                      Biochemistry (sciences)              9         21.0
# 47         Electrical & electronics engineering             12         21.0
# 48                                    Geography              8         16.0
# 49                                       Botany              8          7.0

# %%
training_data
# Out:
#    Unilag Academic_Level             Faculty  \
# 0     Yes      400 Level     Social Sciences
# 1     Yes      500 Level         Engineering
# 2     Yes      400 Level         Engineering
# 3     Yes      300 Level           Education
# 4     Yes      300 Level     Social Sciences
# ..    ...            ...                 ...
# 61    Yes      200 Level           Education
# 62    Yes      200 Level  Management Science
# 63    Yes      200 Level                Arts
# 64    Yes      400 Level           Education
# 65    Yes      200 Level  Management Science
#
#                                  Department  Courses_Taken  Course_Unit
# 0                         Political science              7          0.0
# 1   Surveying & geo-informatics engineering             10          0.0
# 2                      Chemical engineering             10          0.0
# 3                   Educational foundations             10          0.0
# 4                        Mass communication              9          0.0
# ..                                      ...            ...          ...
# 61                  Educational foundations              9          0.0
# 62                               Accounting              8          0.0
# 63                               Philosophy              9          0.0
# 64          Art & social science education               4          0.0
# 65                               Accounting              8          0.0
#
# [66 rows x 6 columns]

# %%
#Define the preprocessor with OneHotEncoder for categorical columns

from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.linear_model import LinearRegression
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
# Define the columns that need to be encoded (categorical columns)
categorical_cols = ['Unilag', 'Academic_Level', 'Faculty',
                    'Department']

# Define the preprocessor with OneHotEncoder for categorical columns and SimpleImputer for missing values

encoder = OneHotEncoder(handle_unknown='ignore')


preprocessor = ColumnTransformer(
    transformers=[
        ('cat', encoder, categorical_cols),
    ],
    remainder='passthrough'  # Place remainder parameter outside the transformers list
)

# %%
# Step 4: Fit and transform the preprocessor on the test data
X_test_processed = preprocessor.fit_transform(X_test)

# Step 5: Train a model on the test data
model = LinearRegression()
model.fit(X_test_processed, y_test)

# Step 6: Use the trained model to predict the missing values in the training data
X_train = training_data.drop(columns=['Course_Unit'])
X_train_processed = preprocessor.transform(X_train)
predicted_values = model.predict(X_train_processed)

# Step 7: Assign the predicted values to the training data
training_data['Course_Unit'] = np.ceil(predicted_values)

# %%
training_data
# Out:
#    Unilag Academic_Level             Faculty  \
# 0     Yes      400 Level     Social Sciences
# 1     Yes      500 Level         Engineering
# 2     Yes      400 Level         Engineering
# 3     Yes      300 Level           Education
# 4     Yes      300 Level     Social Sciences
# ..    ...            ...                 ...
# 61    Yes      200 Level           Education
# 62    Yes      200 Level  Management Science
# 63    Yes      200 Level                Arts
# 64    Yes      400 Level           Education
# 65    Yes      200 Level  Management Science
#
#                                  Department  Courses_Taken  Course_Unit
# 0                         Political science              7         12.0
# 1   Surveying & geo-informatics engineering             10         22.0
# 2                      Chemical engineering             10         23.0
# 3                   Educational foundations             10         17.0
# 4                        Mass communication              9         23.0
# ..                                      ...            ...          ...
# 61                  Educational foundations              9         15.0
# 62                               Accounting              8         19.0
# 63                               Philosophy              9         19.0
# 64          Art & social science education               4         12.0
# 65                               Accounting              8         19.0
#
# [66 rows x 6 columns]

# %%
#create a dataframe containing values from the missing_course_units.df that were not used as a training data set

remaining_data = missing_course_units[~missing_course_units.index.isin(training_data.index)]

# %%
# Concatenate training_data and remaining_data to get the complete dataset
df_course_units = pd.concat([training_data, remaining_data])

len(df_course_units)
# Out:
# 299

# %%
#We still have NaN values in our column
#Drawing a df out that holds any missing values in a column


df_course_units[pd.isna(df_course_units['Course_Unit'])]
# Out:
# Empty DataFrame
# Columns: [Unilag, Academic_Level, Faculty, Department, Courses_Taken, Course_Unit]
# Index: []

# %%
len(df_course_units)
# Out:
# 299

# %% [markdown]
# ##### Well?

# %%
removed_columns = columns_to_drop

# Add the removed columns back to the new DataFrame 'new_df' in place
new_df_unilag= pd.concat([df_course_units, df_unilag[removed_columns]], axis=1)

# Now 'new_df' will have the removed columns added back in place

# %%
new_df_unilag.head(10)
# Out:
#   Unilag Academic_Level             Faculty  \
# 0    Yes      400 Level     Social Sciences
# 1    Yes      500 Level         Engineering
# 2    Yes      400 Level         Engineering
# 3    Yes      300 Level           Education
# 4    Yes      300 Level     Social Sciences
# 5    Yes      400 Level  Management Science
# 6    Yes      300 Level            Sciences
# 7    Yes      300 Level           Education
# 8    Yes      200 Level  Management Science
# 9    Yes      300 Level           Education
#
#                                 Department  Courses_Taken  Course_Unit  \
# 0                        Political science              7         12.0
# 1  Surveying & geo-informatics engineering             10         22.0
# 2                     Chemical engineering             10         23.0
# 3                  Educational foundations             10         17.0
# 4                       Mass communication              9         23.0
# 5                                  Finance              6         17.0
# 6                                   Botany              6         15.0
# 7                  Science tech. education              7         18.0
# 8                                  Finance              7         19.0
# 9                  Educational foundations              8         14.0
#
#                                        Strike_Effect  \
# 0  I learned how to study better and my grades al...
# 1  It affected it in a negative way as it became ...
# 2  It has actually helped me a bit. The extended ...
# 3                                               Good
# 4           Reluctance to concentrate on my studies
# 5                                          No effect
# 6               My grades dropped by a large margin
# 7  The strike helped me with more time to study, ...
# 8                                            Poorly
# 9                                     Still the same
#
#                                     Challenging_Part  \
# 0  Trying to remember things we were taught befor...
# 1  Rekindling the student in me, lol. Trying to g...
# 2                               Readapting to school
# 3                                           Reading
# 4       Getting to dust my books and and assimilate
# 5                                       No challenge
# 6                 I couldn't face my books squarely
# 7  Finding my books and getting back into study m...
# 8                Going back to assignments and exams
# 9                          Prolonged graduating date
#
#                              Job_Undertaken  \
# 0   Worked in a role relevant to my studies
# 1            Did not work during the strike
# 2  Worked in a role unrelated to my studies
# 3  Worked in a role unrelated to my studies
# 4            Did not work during the strike
# 5  Worked in a role unrelated to my studies
# 6  Worked in a role unrelated to my studies
# 7   Worked in a role relevant to my studies
# 8  Worked in a role unrelated to my studies
# 9  Worked in a role unrelated to my studies
#
#                                     Self_Development Exam_Prep_Before_Strike  \
# 0       Acquired skills unrelated to course of study                  Poorly
# 1       Acquired skills unrelated to course of study                  Poorly
# 2  Volunteered for an event or organization, Acqu...              Moderately
# 3       Acquired skills unrelated to course of study              Moderately
# 4                                  None of the above                  Poorly
# 5       Acquired skills unrelated to course of study              Moderately
# 6           Volunteered for an event or organization                    Very
# 7  Acquired skills relevant to course of study, A...              Moderately
# 8                Vocational training and artisanship              Moderately
# 9       Acquired skills unrelated to course of study              Moderately
#
#   Exam_Prep_After_Strike                 Lectures_Affected  \
# 0                 Poorly              No noticeable change
# 1             Moderately              No noticeable change
# 2             Moderately  Fewer lecturers attended classes
# 3                   Very              No noticeable change
# 4                   Very   Worse lectures after the strike
# 5             Moderately              No noticeable change
# 6                 Poorly   Worse lectures after the strike
# 7             Moderately              No noticeable change
# 8                 Poorly  Fewer lecturers attended classes
# 9             Moderately   Worse lectures after the strike
#
#                                  Academic_Activities Relationship_Status  Age  \
# 0  Rarely: I engaged in academic activities once ...              Single   22
# 1  Rarely: I engaged in academic activities once ...              Single   23
# 2  Rarely: I engaged in academic activities once ...              Dating   21
# 3  Rarely: I engaged in academic activities once ...              Dating   29
# 4  Never: I did not engage in any academic activi...              Single   24
# 5  Rarely: I engaged in academic activities once ...              Single   20
# 6  Never: I did not engage in any academic activi...              Single   22
# 7  Rarely: I engaged in academic activities once ...              Single   21
# 8  Rarely: I engaged in academic activities once ...              Dating   23
# 9  Often: I engaged in academic activities regula...              Single   25
#
#    Gender  CGPA_Before  CGPA_After  CGPA Change
# 0    Male         3.39        3.51         0.12
# 1  Female         4.44        4.50         0.06
# 2    Male         3.54        3.61         0.07
# 3    Male         3.86        3.96         0.10
# 4    Male         2.85        2.00        -0.85
# 5  Female         4.00        3.80        -0.20
# 6  Female         3.66        3.50        -0.16
# 7  Female         3.06        3.26         0.20
# 8  Female         3.50        3.49        -0.01
# 9    Male         3.42        3.72         0.30

# %%
# Define the desired column order
desired_order = ['Unilag', 'Academic_Level', 'Age', 'Gender', 'Relationship_Status', 'Faculty',
                 'Department', 'Strike_Effect', 'Challenging_Part', 'Job_Undertaken', 'Self_Development',
                 'Exam_Prep_Before_Strike', 'Exam_Prep_After_Strike', 'Lectures_Affected',
                 'Academic_Activities', 'Courses_Taken', 'Course_Unit', 'CGPA_Before', 'CGPA_After', 'CGPA Change']

# Rearrange the columns of 'new_df' in the desired order
new_df_unilag = new_df_unilag.reindex(columns=desired_order)

# %%
new_df_unilag.head(2)
# Out:
#   Unilag Academic_Level  Age  Gender Relationship_Status          Faculty  \
# 0    Yes      400 Level   22    Male              Single  Social Sciences
# 1    Yes      500 Level   23  Female              Single      Engineering
#
#                                 Department  \
# 0                        Political science
# 1  Surveying & geo-informatics engineering
#
#                                        Strike_Effect  \
# 0  I learned how to study better and my grades al...
# 1  It affected it in a negative way as it became ...
#
#                                     Challenging_Part  \
# 0  Trying to remember things we were taught befor...
# 1  Rekindling the student in me, lol. Trying to g...
#
#                             Job_Undertaken  \
# 0  Worked in a role relevant to my studies
# 1           Did not work during the strike
#
#                                Self_Development Exam_Prep_Before_Strike  \
# 0  Acquired skills unrelated to course of study                  Poorly
# 1  Acquired skills unrelated to course of study                  Poorly
#
#   Exam_Prep_After_Strike     Lectures_Affected  \
# 0                 Poorly  No noticeable change
# 1             Moderately  No noticeable change
#
#                                  Academic_Activities  Courses_Taken  \
# 0  Rarely: I engaged in academic activities once ...              7
# 1  Rarely: I engaged in academic activities once ...             10
#
#    Course_Unit  CGPA_Before  CGPA_After  CGPA Change
# 0         12.0         3.39        3.51         0.12
# 1         22.0         4.44        4.50         0.06
